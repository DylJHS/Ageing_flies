# %%
# Description:
"""
This script processes a single-nucleus RNA-seq dataset from afca, removes cells with unspecified sex, 
and filters cell types with fewer than 200 total cells or fewer than 100 cells per age group. For each remaining cell type, 
it filters out lowly expressed genes, while retaining those expressed in at least 3 cells or included in the predefined gene list. 
Each processed cell type is saved as a separate .h5ad file.
"""

# Import the libraries
import os
import re
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scanpy as sc
import anndata as ad

# %%
# load the dataset data and get the metadata
adata = ad.read_h5ad("/hpc/shared/onco_janssen/dhaynessimmons/projects/ageing_flies/data/adata_body_S_v1.0.h5ad")

# %%
# Set the functions
def split_by_batch_prefix(name):
    """
    Splits the string into two parts:
    - Part before 'AFCA' or 'FCA'
    - The rest starting with 'AFCA' or 'FCA'
    """
    match = re.search(r'(AFCA|FCA)', name)
    i = match.start()
    return name[i:]

# %%
# print out the basics
print([i for i in adata.obs.columns])
print("shape of full data: ", adata.shape)
#value couns for important columns
print("\nAge value counts: ", adata.obs["age"].value_counts())
print("\nSex value counts: ", adata.obs["sex"].value_counts())
print("\nDataset value counts: ", adata.obs["dataset"].value_counts())
# Out:
# ['tissue', 'sex', 'age', 'sex_age', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'log1p_total_counts_mt', 'dataset', 'fca_annotation', 'afca_annotation', 'afca_annotation_broad']
# shape of full data:  (276273, 15992)
#
# Age value counts:  age
# 5     96594
# 30    84496
# 70    49963
# 50    45220
# Name: count, dtype: int64
#
# Sex value counts:  sex
# female    148049
# male      123879
# mix         4345
# Name: count, dtype: int64
#
# Dataset value counts:  dataset
# AFCA    179679
# FCA      96594
# Name: count, dtype: int64

# %%
# Get the unique afca cell types
for cell_type in sorted(adata.obs['afca_annotation'].unique().tolist()):
    print(cell_type)
# Out:
# 16-cell germline cyst in germarium region 2a and 2b
# CNS surface associated glial cell
# adult Malpighian tubule principal cell
# adult Malpighian tubule principal cell of initial segment
# adult Malpighian tubule principal cell of lower segment
# adult Malpighian tubule principal cell of lower ureter
# adult Malpighian tubule stellate cell of main segment
# adult alary muscle
# adult differentiating enterocyte
# adult fat body_body
# adult glial cell
# adult heart ventral longitudinal muscle
# adult hindgut
# adult midgut enterocyte
# adult midgut-hindgut hybrid zone
# adult oenocyte
# adult peripheral nervous system
# adult reticular neuropil associated glial cell_body
# adult salivary gland
# adult tracheal cell
# adult ventral nervous system
# anterior ejaculatory duct
# antimicrobial peptide-producing cell
# cardia (1)
# cardia (2)
# cardiomyocyte, working adult heart muscle (non-ostia)
# cell body glial cell
# copper cell
# crop
# cyst cell
# ejaculatory bulb
# ejaculatory bulb epithelium
# enteroblast
# enterocyte of anterior adult midgut epithelium
# enterocyte of posterior adult midgut epithelium
# enterocyte-like
# enteroendocrine cell
# eo support cell
# epidermal cell that specialized in antimicrobial response
# epithelial cell_body
# escort cell
# female reproductive system
# follicle cell
# follicle stem cell and prefollicle cell
# germline cell
# gustatory receptor neuron
# hemocyte_body
# indirect flight muscle
# intestinal stem cell
# leg muscle motor neuron
# male accessory gland main cell
# male accessory gland secondary cell
# mechanosensory neuron of haltere
# midgut large flat cell
# multidendritic neuron
# muscle cell
# oviduct
# perineurial glial sheath
# pheromone-sensing neuron
# polar follicle cell
# posterior midgut*
# prefollicle cell/stalk follicle cell
# principal cell*
# scolopidial neuron
# seminal vesicle & testis epithelia
# spermatid
# spermatocyte
# stalk follicle cell
# subperineurial glial cell_body
# unannotated
# visceral muscle of the crop
# visceral muscle of the midgut
# young germ cell

# %%
# get cells where sex is neither F nor M
mix_adata = adata[(adata.obs.sex != "female")&(adata.obs.sex != "male")].copy()
print(mix_adata.obs.shape)
# Remove them from the dataset
mf_adata = adata[~(adata.obs.index.isin(mix_adata.obs.index))&(adata.obs['afca_annotation'] != "unannotated")].copy()
# get the batch from the row name
mf_adata.obs['indiv'] = mf_adata.obs.index.map(lambda x: split_by_batch_prefix(x))
print(mf_adata.obs.shape)
# Out:
# (4345, 15)
# (265979, 16)

# %%
# Get the observation dataframe as a pandas dataframe
mf_adata_obs = mf_adata.obs.copy()
print(type(mf_adata_obs))
cell_list = []

# Set the save path 
save_path = "/hpc/shared/onco_janssen/dhaynessimmons/projects/ageing_flies/data/ct_specific/"
os.makedirs(save_path, exist_ok=True)

# Gene list of interest
gene_list = [
    "Su(var)205", "Su(var)3-9", "G9a", "HP1b", "HP1c", "HP4",
    "HP5", "HP6", "ADD1", "Su(var)2-HP2", "Su(var)3-7", "Lam",
    "LamC", "LBR", "Kdm4A", "Kdm4B", "His2Av", "His3.3A", "His3.3B"
]

# Loop through the afca cell types and create a new adata object for each cell type
for cell_type in mf_adata_obs['afca_annotation'].unique():
    print("\n\nWorking on cell type: ", cell_type, "\n")	

    # Editting the cell type name to make it a valid file name
    cell_name = cell_type.replace(" ", "_").replace("/", "_")

    # Get the indices of the cells that match the current cell type
    indices = mf_adata_obs[mf_adata_obs['afca_annotation'] == cell_type].index
    # Create new pandas dataframe with the indices
    cell_type_df = mf_adata_obs.loc[indices]

    # Evaluate the QC of the new adata object
    cell_cnt = cell_type_df.shape[0]
    print("number of cells: ", cell_cnt)
    print("Min number of genes expressed : ", cell_type_df.n_genes_by_counts.min())

    if cell_cnt < 200:
        print("Not enough cells to proceed with analysis")
        continue
    else:
        print("Sufficient cells to proceed with analysis")

        # Check that each age group has at least 100 cells
        age_grouped = cell_type_df.groupby('age', observed=False).size()
        del cell_type_df
        min_value = age_grouped.min()
        del age_grouped
        print("Minimum number of cells in an age group: ", min_value)
        if min_value < 100:
            print("Not enough cells in an age group to proceed with analysis")
            continue
        else:
            print("Sufficient cells in each age group to proceed with analysis")
            # Create a new adata object with the cell type data
            cell_list.append(cell_type)

    # Create a new adata object for this cell type
    cell_type_adata = mf_adata[indices].copy()
    print("\nshape of cell type data: ", cell_type_adata.shape)


    # ----------- Custom gene filtering starts here ------------ #

    # Compute how many cells express each gene
    gene_expression_counts = np.array((cell_type_adata.X > 0).sum(axis=0)).flatten()

    # Get gene names
    gene_names = pd.Index(cell_type_adata.var_names)

    # Genes expressed in >= 3 cells
    genes_expressed_enough = gene_expression_counts >= 3

    # Create a boolean mask to keep genes that are either:
    # - expressed in enough cells
    # - or present in the gene_list
    gene_list_set = set(gene_list)
    genes_in_list = gene_names.isin(gene_list_set)

    # Combine masks
    genes_to_keep = genes_expressed_enough | genes_in_list

    # Filter genes
    cell_type_adata = cell_type_adata[:, genes_to_keep].copy()

    print("\nshape of cell type data after filtering: ", cell_type_adata.shape)
    print("Columns in the observation dataframe: ", cell_type_adata.obs.columns)
    print(cell_type_adata.obs.iloc[:, -3:])
 

    # ----------- End of custom filtering ------------ #

    # Save the new adata object
    cell_type_adata.write_h5ad(f"{save_path}{cell_name}.h5ad")
    print("\n\tSaved the new adata object to: ", f"{save_path}{cell_name}.h5ad\n")

# Print list of successfully processed cell types
print(cell_list)
del mf_adata_obs
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
#
# Working on cell type:  follicle cell
#
# number of cells:  25251
# Min number of genes expressed :  226
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  5826
# Sufficient cells in each age group to proceed with analysis
#
# shape of cell type data:  (25251, 15992)
#
# shape of cell type data after filtering:  (25251, 12468)
# Columns in the observation dataframe:  Index(['tissue', 'sex', 'age', 'sex_age', 'n_genes_by_counts', 'total_counts',
#        'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts',
#        'log1p_total_counts', 'log1p_total_counts_mt', 'dataset',
#        'fca_annotation', 'afca_annotation', 'afca_annotation_broad', 'indiv'],
#       dtype='object')
#                                                    afca_annotation  \
# AAACCCAAGGATACAT-1_AFCA_female_body_30_S1            follicle cell
# AAACGAAAGGAGTCTG-1_AFCA_female_body_30_S1            follicle cell
# AAAGAACAGCTGAGCA-1_AFCA_female_body_30_S1            follicle cell
# AAAGAACTCCTCGCAT-1_AFCA_female_body_30_S1            follicle cell
# AAAGTCCTCACCCTGT-1_AFCA_female_body_30_S1            follicle cell
# ...                                                            ...
# TTTCGATTCTGTCAGA-f8548b44__FCA27_Female_body_adult   follicle cell
# TTTGACTGTCTTGGTA-f8548b44__FCA27_Female_body_adult   follicle cell
# TTTGATCTCCCTTTGG-f8548b44__FCA27_Female_body_adult   follicle cell
# TTTGGTTGTGAACTAA-f8548b44__FCA27_Female_body_adult   follicle cell
# TTTGGTTGTTAGTCGT-f8548b44__FCA27_Female_body_adult   follicle cell
#
#                                                          afca_annotation_broad  \
# AAACCCAAGGATACAT-1_AFCA_female_body_30_S1           female reproductive system
# AAACGAAAGGAGTCTG-1_AFCA_female_body_30_S1           female reproductive system
# AAAGAACAGCTGAGCA-1_AFCA_female_body_30_S1           female reproductive system
# AAAGAACTCCTCGCAT-1_AFCA_female_body_30_S1           female reproductive system
# AAAGTCCTCACCCTGT-1_AFCA_female_body_30_S1           female reproductive system
# ...                                                                        ...
# TTTCGATTCTGTCAGA-f8548b44__FCA27_Female_body_adult  female reproductive system
# TTTGACTGTCTTGGTA-f8548b44__FCA27_Female_body_adult  female reproductive system
# TTTGATCTCCCTTTGG-f8548b44__FCA27_Female_body_adult  female reproductive system
# TTTGGTTGTGAACTAA-f8548b44__FCA27_Female_body_adult  female reproductive system
# TTTGGTTGTTAGTCGT-f8548b44__FCA27_Female_body_adult  female reproductive system
#
#                                                                       indiv
# AAACCCAAGGATACAT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AAACGAAAGGAGTCTG-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AAAGAACAGCTGAGCA-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AAAGAACTCCTCGCAT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AAAGTCCTCACCCTGT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ...                                                                     ...
# TTTCGATTCTGTCAGA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTGACTGTCTTGGTA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTGATCTCCCTTTGG-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTGGTTGTGAACTAA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTGGTTGTTAGTCGT-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
#
# [25251 rows x 3 columns]
#
# 	Saved the new adata object to:  /hpc/shared/onco_janssen/dhaynessimmons/data/ageing_flies/afca_data/base_body_h5ad_data/ct_specific/follicle_cell.h5ad
#
#
#
# Working on cell type:  adult fat body_body
#
# number of cells:  31311
# Min number of genes expressed :  224
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  2703
# Sufficient cells in each age group to proceed with analysis
#
# shape of cell type data:  (31311, 15992)
#
# shape of cell type data after filtering:  (31311, 13796)
# Columns in the observation dataframe:  Index(['tissue', 'sex', 'age', 'sex_age', 'n_genes_by_counts', 'total_counts',
#        'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts',
#        'log1p_total_counts', 'log1p_total_counts_mt', 'dataset',
#        'fca_annotation', 'afca_annotation', 'afca_annotation_broad', 'indiv'],
#       dtype='object')
#                                                         afca_annotation  \
# AAACCCAGTGCAATAA-1_AFCA_female_body_30_S1           adult fat body_body
# AAACCCATCCGATGTA-1_AFCA_female_body_30_S1           adult fat body_body
# AAACCCATCGTGGGTC-1_AFCA_female_body_30_S1           adult fat body_body
# AAACGCTCACTAGGCC-1_AFCA_female_body_30_S1           adult fat body_body
# AAACGCTTCTCGCAGG-1_AFCA_female_body_30_S1           adult fat body_body
# ...                                                                 ...
# TTTAGTCAGAGCATCG-f8548b44__FCA27_Female_body_adult  adult fat body_body
# TTTAGTCCAACAGCCC-f8548b44__FCA27_Female_body_adult  adult fat body_body
# TTTCAGTCAGGACTTT-f8548b44__FCA27_Female_body_adult  adult fat body_body
# TTTGATCAGGGATCAC-f8548b44__FCA27_Female_body_adult  adult fat body_body
# TTTGGAGAGTGTTCCA-f8548b44__FCA27_Female_body_adult  adult fat body_body
#
#                                                    afca_annotation_broad  \
# AAACCCAGTGCAATAA-1_AFCA_female_body_30_S1                       fat cell
# AAACCCATCCGATGTA-1_AFCA_female_body_30_S1                       fat cell
# AAACCCATCGTGGGTC-1_AFCA_female_body_30_S1                       fat cell
# AAACGCTCACTAGGCC-1_AFCA_female_body_30_S1                       fat cell
# AAACGCTTCTCGCAGG-1_AFCA_female_body_30_S1                       fat cell
# ...                                                                  ...
# TTTAGTCAGAGCATCG-f8548b44__FCA27_Female_body_adult              fat cell
# TTTAGTCCAACAGCCC-f8548b44__FCA27_Female_body_adult              fat cell
# TTTCAGTCAGGACTTT-f8548b44__FCA27_Female_body_adult              fat cell
# TTTGATCAGGGATCAC-f8548b44__FCA27_Female_body_adult              fat cell
# TTTGGAGAGTGTTCCA-f8548b44__FCA27_Female_body_adult              fat cell
#
#                                                                       indiv
# AAACCCAGTGCAATAA-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AAACCCATCCGATGTA-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AAACCCATCGTGGGTC-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AAACGCTCACTAGGCC-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AAACGCTTCTCGCAGG-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ...                                                                     ...
# TTTAGTCAGAGCATCG-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTAGTCCAACAGCCC-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTCAGTCAGGACTTT-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTGATCAGGGATCAC-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTGGAGAGTGTTCCA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
#
# [31311 rows x 3 columns]
#
# 	Saved the new adata object to:  /hpc/shared/onco_janssen/dhaynessimmons/data/ageing_flies/afca_data/base_body_h5ad_data/ct_specific/adult_fat_body_body.h5ad
#
#
#
# Working on cell type:  adult hindgut
#
# number of cells:  683
# Min number of genes expressed :  286
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  146
# Sufficient cells in each age group to proceed with analysis
#
# shape of cell type data:  (683, 15992)
#
# shape of cell type data after filtering:  (683, 8910)
# Columns in the observation dataframe:  Index(['tissue', 'sex', 'age', 'sex_age', 'n_genes_by_counts', 'total_counts',
#        'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts',
#        'log1p_total_counts', 'log1p_total_counts_mt', 'dataset',
#        'fca_annotation', 'afca_annotation', 'afca_annotation_broad', 'indiv'],
#       dtype='object')
#                                                    afca_annotation  \
# AAACGCTCACAAGCAG-1_AFCA_female_body_30_S1            adult hindgut
# ACTCTCGCATGTCTAG-1_AFCA_female_body_30_S1            adult hindgut
# ACTGTGAGTGACTGTT-1_AFCA_female_body_30_S1            adult hindgut
# AGATGCTGTTGTGGCC-1_AFCA_female_body_30_S1            adult hindgut
# AGCCACGGTACCGTGC-1_AFCA_female_body_30_S1            adult hindgut
# ...                                                            ...
# TGCAGTAAGAAGCTGC-f8548b44__FCA27_Female_body_adult   adult hindgut
# TGTAACGCATCGCTCT-f8548b44__FCA27_Female_body_adult   adult hindgut
# TGTAGACGTGGCGCTT-f8548b44__FCA27_Female_body_adult   adult hindgut
# TGTCCACAGAGTGTGC-f8548b44__FCA27_Female_body_adult   adult hindgut
# TGTTACTAGATCACTC-f8548b44__FCA27_Female_body_adult   adult hindgut
#
#                                                    afca_annotation_broad  \
# AAACGCTCACAAGCAG-1_AFCA_female_body_30_S1                epithelial cell
# ACTCTCGCATGTCTAG-1_AFCA_female_body_30_S1                epithelial cell
# ACTGTGAGTGACTGTT-1_AFCA_female_body_30_S1                epithelial cell
# AGATGCTGTTGTGGCC-1_AFCA_female_body_30_S1                epithelial cell
# AGCCACGGTACCGTGC-1_AFCA_female_body_30_S1                epithelial cell
# ...                                                                  ...
# TGCAGTAAGAAGCTGC-f8548b44__FCA27_Female_body_adult       epithelial cell
# TGTAACGCATCGCTCT-f8548b44__FCA27_Female_body_adult       epithelial cell
# TGTAGACGTGGCGCTT-f8548b44__FCA27_Female_body_adult       epithelial cell
# TGTCCACAGAGTGTGC-f8548b44__FCA27_Female_body_adult       epithelial cell
# TGTTACTAGATCACTC-f8548b44__FCA27_Female_body_adult       epithelial cell
#
#                                                                       indiv
# AAACGCTCACAAGCAG-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ACTCTCGCATGTCTAG-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ACTGTGAGTGACTGTT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AGATGCTGTTGTGGCC-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AGCCACGGTACCGTGC-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ...                                                                     ...
# TGCAGTAAGAAGCTGC-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TGTAACGCATCGCTCT-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TGTAGACGTGGCGCTT-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TGTCCACAGAGTGTGC-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TGTTACTAGATCACTC-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
#
# [683 rows x 3 columns]
#
# 	Saved the new adata object to:  /hpc/shared/onco_janssen/dhaynessimmons/data/ageing_flies/afca_data/base_body_h5ad_data/ct_specific/adult_hindgut.h5ad
#
#
#
# Working on cell type:  adult oenocyte
#
# number of cells:  5925
# Min number of genes expressed :  233
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  1081
# Sufficient cells in each age group to proceed with analysis
#
# shape of cell type data:  (5925, 15992)
#
# shape of cell type data after filtering:  (5925, 11683)
# Columns in the observation dataframe:  Index(['tissue', 'sex', 'age', 'sex_age', 'n_genes_by_counts', 'total_counts',
#        'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts',
#        'log1p_total_counts', 'log1p_total_counts_mt', 'dataset',
#        'fca_annotation', 'afca_annotation', 'afca_annotation_broad', 'indiv'],
#       dtype='object')
#                                                    afca_annotation  \
# AAACGCTGTACCTAGT-1_AFCA_female_body_30_S1           adult oenocyte
# AAAGGATTCGCATTGA-1_AFCA_female_body_30_S1           adult oenocyte
# AAAGTCCAGGTCGAGT-1_AFCA_female_body_30_S1           adult oenocyte
# AAAGTGATCGCTGTCT-1_AFCA_female_body_30_S1           adult oenocyte
# AACAAGATCGAGATAA-1_AFCA_female_body_30_S1           adult oenocyte
# ...                                                            ...
# TTTATGCTCCACATAG-f8548b44__FCA27_Female_body_adult  adult oenocyte
# TTTCCTCAGTCTCCTC-f8548b44__FCA27_Female_body_adult  adult oenocyte
# TTTGATCCACAACGAG-f8548b44__FCA27_Female_body_adult  adult oenocyte
# TTTGATCGTGCCCACA-f8548b44__FCA27_Female_body_adult  adult oenocyte
# TTTGATCTCCTCTGCA-f8548b44__FCA27_Female_body_adult  adult oenocyte
#
#                                                    afca_annotation_broad  \
# AAACGCTGTACCTAGT-1_AFCA_female_body_30_S1                       oenocyte
# AAAGGATTCGCATTGA-1_AFCA_female_body_30_S1                       oenocyte
# AAAGTCCAGGTCGAGT-1_AFCA_female_body_30_S1                       oenocyte
# AAAGTGATCGCTGTCT-1_AFCA_female_body_30_S1                       oenocyte
# AACAAGATCGAGATAA-1_AFCA_female_body_30_S1                       oenocyte
# ...                                                                  ...
# TTTATGCTCCACATAG-f8548b44__FCA27_Female_body_adult              oenocyte
# TTTCCTCAGTCTCCTC-f8548b44__FCA27_Female_body_adult              oenocyte
# TTTGATCCACAACGAG-f8548b44__FCA27_Female_body_adult              oenocyte
# TTTGATCGTGCCCACA-f8548b44__FCA27_Female_body_adult              oenocyte
# TTTGATCTCCTCTGCA-f8548b44__FCA27_Female_body_adult              oenocyte
#
#                                                                       indiv
# AAACGCTGTACCTAGT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AAAGGATTCGCATTGA-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AAAGTCCAGGTCGAGT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AAAGTGATCGCTGTCT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AACAAGATCGAGATAA-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ...                                                                     ...
# TTTATGCTCCACATAG-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTCCTCAGTCTCCTC-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTGATCCACAACGAG-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTGATCGTGCCCACA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTGATCTCCTCTGCA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
#
# [5925 rows x 3 columns]
#
# 	Saved the new adata object to:  /hpc/shared/onco_janssen/dhaynessimmons/data/ageing_flies/afca_data/base_body_h5ad_data/ct_specific/adult_oenocyte.h5ad
#
#
#
# Working on cell type:  hemocyte_body
#
# number of cells:  2962
# Min number of genes expressed :  213
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  560
# Sufficient cells in each age group to proceed with analysis
#
# shape of cell type data:  (2962, 15992)
#
# shape of cell type data after filtering:  (2962, 10540)
# Columns in the observation dataframe:  Index(['tissue', 'sex', 'age', 'sex_age', 'n_genes_by_counts', 'total_counts',
#        'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts',
#        'log1p_total_counts', 'log1p_total_counts_mt', 'dataset',
#        'fca_annotation', 'afca_annotation', 'afca_annotation_broad', 'indiv'],
#       dtype='object')
#                                                    afca_annotation  \
# AAACGCTGTAGTCGTT-1_AFCA_female_body_30_S1            hemocyte_body
# AGAAATGTCGTTAGTG-1_AFCA_female_body_30_S1            hemocyte_body
# AGCCACGCAATCGAAA-1_AFCA_female_body_30_S1            hemocyte_body
# AGCGATTAGCGACATG-1_AFCA_female_body_30_S1            hemocyte_body
# AGCTACACAATACCCA-1_AFCA_female_body_30_S1            hemocyte_body
# ...                                                            ...
# TGTTGGAAGCTCTATG-f8548b44__FCA27_Female_body_adult   hemocyte_body
# TTACAGGTCCACGTAA-f8548b44__FCA27_Female_body_adult   hemocyte_body
# TTCTAGTAGATACCAA-f8548b44__FCA27_Female_body_adult   hemocyte_body
# TTGGATGGTTCGGCCA-f8548b44__FCA27_Female_body_adult   hemocyte_body
# TTGTTCATCTTAAGGC-f8548b44__FCA27_Female_body_adult   hemocyte_body
#
#                                                    afca_annotation_broad  \
# AAACGCTGTAGTCGTT-1_AFCA_female_body_30_S1                       hemocyte
# AGAAATGTCGTTAGTG-1_AFCA_female_body_30_S1                       hemocyte
# AGCCACGCAATCGAAA-1_AFCA_female_body_30_S1                       hemocyte
# AGCGATTAGCGACATG-1_AFCA_female_body_30_S1                       hemocyte
# AGCTACACAATACCCA-1_AFCA_female_body_30_S1                       hemocyte
# ...                                                                  ...
# TGTTGGAAGCTCTATG-f8548b44__FCA27_Female_body_adult              hemocyte
# TTACAGGTCCACGTAA-f8548b44__FCA27_Female_body_adult              hemocyte
# TTCTAGTAGATACCAA-f8548b44__FCA27_Female_body_adult              hemocyte
# TTGGATGGTTCGGCCA-f8548b44__FCA27_Female_body_adult              hemocyte
# TTGTTCATCTTAAGGC-f8548b44__FCA27_Female_body_adult              hemocyte
#
#                                                                       indiv
# AAACGCTGTAGTCGTT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AGAAATGTCGTTAGTG-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AGCCACGCAATCGAAA-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AGCGATTAGCGACATG-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AGCTACACAATACCCA-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ...                                                                     ...
# TGTTGGAAGCTCTATG-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTACAGGTCCACGTAA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTCTAGTAGATACCAA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTGGATGGTTCGGCCA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTGTTCATCTTAAGGC-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
#
# [2962 rows x 3 columns]
#
# 	Saved the new adata object to:  /hpc/shared/onco_janssen/dhaynessimmons/data/ageing_flies/afca_data/base_body_h5ad_data/ct_specific/hemocyte_body.h5ad
#
#
#
# Working on cell type:  adult tracheal cell
#
# number of cells:  6939
# Min number of genes expressed :  207
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  1154
# Sufficient cells in each age group to proceed with analysis
#
# shape of cell type data:  (6939, 15992)
#
# shape of cell type data after filtering:  (6939, 11967)
# Columns in the observation dataframe:  Index(['tissue', 'sex', 'age', 'sex_age', 'n_genes_by_counts', 'total_counts',
#        'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts',
#        'log1p_total_counts', 'log1p_total_counts_mt', 'dataset',
#        'fca_annotation', 'afca_annotation', 'afca_annotation_broad', 'indiv'],
#       dtype='object')
#                                                         afca_annotation  \
# AAAGAACCATAATCCG-1_AFCA_female_body_30_S1           adult tracheal cell
# AACAAAGTCCAACCAA-1_AFCA_female_body_30_S1           adult tracheal cell
# AACAAGACACTAGGTT-1_AFCA_female_body_30_S1           adult tracheal cell
# AACTTCTTCGTGCTCT-1_AFCA_female_body_30_S1           adult tracheal cell
# AAGCATCAGACAACAT-1_AFCA_female_body_30_S1           adult tracheal cell
# ...                                                                 ...
# TTGTTTGTCAATCTTC-f8548b44__FCA27_Female_body_adult  adult tracheal cell
# TTTACTGAGTGTAGTA-f8548b44__FCA27_Female_body_adult  adult tracheal cell
# TTTCACATCTCAAAGC-f8548b44__FCA27_Female_body_adult  adult tracheal cell
# TTTGACTCAGTATACC-f8548b44__FCA27_Female_body_adult  adult tracheal cell
# TTTGTTGTCGGAAACG-f8548b44__FCA27_Female_body_adult  adult tracheal cell
#
#                                                    afca_annotation_broad  \
# AAAGAACCATAATCCG-1_AFCA_female_body_30_S1                     glial cell
# AACAAAGTCCAACCAA-1_AFCA_female_body_30_S1                  tracheal cell
# AACAAGACACTAGGTT-1_AFCA_female_body_30_S1                epithelial cell
# AACTTCTTCGTGCTCT-1_AFCA_female_body_30_S1                  tracheal cell
# AAGCATCAGACAACAT-1_AFCA_female_body_30_S1                epithelial cell
# ...                                                                  ...
# TTGTTTGTCAATCTTC-f8548b44__FCA27_Female_body_adult         tracheal cell
# TTTACTGAGTGTAGTA-f8548b44__FCA27_Female_body_adult         tracheal cell
# TTTCACATCTCAAAGC-f8548b44__FCA27_Female_body_adult         tracheal cell
# TTTGACTCAGTATACC-f8548b44__FCA27_Female_body_adult         tracheal cell
# TTTGTTGTCGGAAACG-f8548b44__FCA27_Female_body_adult         tracheal cell
#
#                                                                       indiv
# AAAGAACCATAATCCG-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AACAAAGTCCAACCAA-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AACAAGACACTAGGTT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AACTTCTTCGTGCTCT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AAGCATCAGACAACAT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ...                                                                     ...
# TTGTTTGTCAATCTTC-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTACTGAGTGTAGTA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTCACATCTCAAAGC-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTGACTCAGTATACC-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTGTTGTCGGAAACG-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
#
# [6939 rows x 3 columns]
#
# 	Saved the new adata object to:  /hpc/shared/onco_janssen/dhaynessimmons/data/ageing_flies/afca_data/base_body_h5ad_data/ct_specific/adult_tracheal_cell.h5ad
#
#
#
# Working on cell type:  crop
#
# number of cells:  6226
# Min number of genes expressed :  261
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  1051
# Sufficient cells in each age group to proceed with analysis
#
# shape of cell type data:  (6226, 15992)
#
# shape of cell type data after filtering:  (6226, 11708)
# Columns in the observation dataframe:  Index(['tissue', 'sex', 'age', 'sex_age', 'n_genes_by_counts', 'total_counts',
#        'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts',
#        'log1p_total_counts', 'log1p_total_counts_mt', 'dataset',
#        'fca_annotation', 'afca_annotation', 'afca_annotation_broad', 'indiv'],
#       dtype='object')
#                                                    afca_annotation  \
# AAAGAACTCAACTGGT-1_AFCA_female_body_30_S1                     crop
# AAAGGGCTCCGAACGC-1_AFCA_female_body_30_S1                     crop
# AAATGGAAGACTGTTC-1_AFCA_female_body_30_S1                     crop
# AACAAAGTCCCATACC-1_AFCA_female_body_30_S1                     crop
# AACCAACAGGAAAGTG-1_AFCA_female_body_30_S1                     crop
# ...                                                            ...
# TTTCACATCCGTCCTA-f8548b44__FCA27_Female_body_adult            crop
# TTTCAGTCATATCTGG-f8548b44__FCA27_Female_body_adult            crop
# TTTCATGTCTGCATGA-f8548b44__FCA27_Female_body_adult            crop
# TTTCCTCCACCCTATC-f8548b44__FCA27_Female_body_adult            crop
# TTTGATCGTGCTCCGA-f8548b44__FCA27_Female_body_adult            crop
#
#                                                    afca_annotation_broad  \
# AAAGAACTCAACTGGT-1_AFCA_female_body_30_S1                epithelial cell
# AAAGGGCTCCGAACGC-1_AFCA_female_body_30_S1                epithelial cell
# AAATGGAAGACTGTTC-1_AFCA_female_body_30_S1                epithelial cell
# AACAAAGTCCCATACC-1_AFCA_female_body_30_S1                epithelial cell
# AACCAACAGGAAAGTG-1_AFCA_female_body_30_S1                epithelial cell
# ...                                                                  ...
# TTTCACATCCGTCCTA-f8548b44__FCA27_Female_body_adult       epithelial cell
# TTTCAGTCATATCTGG-f8548b44__FCA27_Female_body_adult       epithelial cell
# TTTCATGTCTGCATGA-f8548b44__FCA27_Female_body_adult       epithelial cell
# TTTCCTCCACCCTATC-f8548b44__FCA27_Female_body_adult       epithelial cell
# TTTGATCGTGCTCCGA-f8548b44__FCA27_Female_body_adult       epithelial cell
#
#                                                                       indiv
# AAAGAACTCAACTGGT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AAAGGGCTCCGAACGC-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AAATGGAAGACTGTTC-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AACAAAGTCCCATACC-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AACCAACAGGAAAGTG-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ...                                                                     ...
# TTTCACATCCGTCCTA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTCAGTCATATCTGG-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTCATGTCTGCATGA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTCCTCCACCCTATC-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTGATCGTGCTCCGA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
#
# [6226 rows x 3 columns]
#
# 	Saved the new adata object to:  /hpc/shared/onco_janssen/dhaynessimmons/data/ageing_flies/afca_data/base_body_h5ad_data/ct_specific/crop.h5ad
#
#
#
# Working on cell type:  adult ventral nervous system
#
# number of cells:  22172
# Min number of genes expressed :  271
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  3454
# Sufficient cells in each age group to proceed with analysis
#
# shape of cell type data:  (22172, 15992)
#
# shape of cell type data after filtering:  (22172, 14032)
# Columns in the observation dataframe:  Index(['tissue', 'sex', 'age', 'sex_age', 'n_genes_by_counts', 'total_counts',
#        'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts',
#        'log1p_total_counts', 'log1p_total_counts_mt', 'dataset',
#        'fca_annotation', 'afca_annotation', 'afca_annotation_broad', 'indiv'],
#       dtype='object')
#                                                                  afca_annotation  \
# AAAGAACTCAGGTAAA-1_AFCA_female_body_30_S1           adult ventral nervous system
# AAAGGGCCAGTTAAAG-1_AFCA_female_body_30_S1           adult ventral nervous system
# AACAAAGAGTTTCGGT-1_AFCA_female_body_30_S1           adult ventral nervous system
# AACAGGGGTACCTTCC-1_AFCA_female_body_30_S1           adult ventral nervous system
# AACCACAGTTATGACC-1_AFCA_female_body_30_S1           adult ventral nervous system
# ...                                                                          ...
# TTTACTGAGGCCTGCT-f8548b44__FCA27_Female_body_adult  adult ventral nervous system
# TTTAGTCTCCGACATA-f8548b44__FCA27_Female_body_adult  adult ventral nervous system
# TTTATGCTCTGAGTCA-f8548b44__FCA27_Female_body_adult  adult ventral nervous system
# TTTCCTCCAGAGTTCT-f8548b44__FCA27_Female_body_adult  adult ventral nervous system
# TTTGGTTCATGCTGCG-f8548b44__FCA27_Female_body_adult  adult ventral nervous system
#
#                                                    afca_annotation_broad  \
# AAAGAACTCAGGTAAA-1_AFCA_female_body_30_S1                     CNS neuron
# AAAGGGCCAGTTAAAG-1_AFCA_female_body_30_S1                     CNS neuron
# AACAAAGAGTTTCGGT-1_AFCA_female_body_30_S1                     CNS neuron
# AACAGGGGTACCTTCC-1_AFCA_female_body_30_S1                     CNS neuron
# AACCACAGTTATGACC-1_AFCA_female_body_30_S1                     CNS neuron
# ...                                                                  ...
# TTTACTGAGGCCTGCT-f8548b44__FCA27_Female_body_adult            CNS neuron
# TTTAGTCTCCGACATA-f8548b44__FCA27_Female_body_adult            CNS neuron
# TTTATGCTCTGAGTCA-f8548b44__FCA27_Female_body_adult            CNS neuron
# TTTCCTCCAGAGTTCT-f8548b44__FCA27_Female_body_adult            CNS neuron
# TTTGGTTCATGCTGCG-f8548b44__FCA27_Female_body_adult            CNS neuron
#
#                                                                       indiv
# AAAGAACTCAGGTAAA-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AAAGGGCCAGTTAAAG-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AACAAAGAGTTTCGGT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AACAGGGGTACCTTCC-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AACCACAGTTATGACC-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ...                                                                     ...
# TTTACTGAGGCCTGCT-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTAGTCTCCGACATA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTATGCTCTGAGTCA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTCCTCCAGAGTTCT-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTGGTTCATGCTGCG-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
#
# [22172 rows x 3 columns]
#
# 	Saved the new adata object to:  /hpc/shared/onco_janssen/dhaynessimmons/data/ageing_flies/afca_data/base_body_h5ad_data/ct_specific/adult_ventral_nervous_system.h5ad
#
#
#
# Working on cell type:  enteroendocrine cell
#
# number of cells:  529
# Min number of genes expressed :  268
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  75
# Not enough cells in an age group to proceed with analysis
#
#
# Working on cell type:  germline cell
#
# number of cells:  3824
# Min number of genes expressed :  208
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  435
# Sufficient cells in each age group to proceed with analysis
#
# shape of cell type data:  (3824, 15992)
#
# shape of cell type data after filtering:  (3824, 10739)
# Columns in the observation dataframe:  Index(['tissue', 'sex', 'age', 'sex_age', 'n_genes_by_counts', 'total_counts',
#        'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts',
#        'log1p_total_counts', 'log1p_total_counts_mt', 'dataset',
#        'fca_annotation', 'afca_annotation', 'afca_annotation_broad', 'indiv'],
#       dtype='object')
#                                                    afca_annotation  \
# AAAGGTATCACTTCTA-1_AFCA_female_body_30_S1            germline cell
# AACCCAACACCCTATC-1_AFCA_female_body_30_S1            germline cell
# AACGAAATCTATTTCG-1_AFCA_female_body_30_S1            germline cell
# AAGAACAAGGACAACC-1_AFCA_female_body_30_S1            germline cell
# AAGCATCTCAAGAGTA-1_AFCA_female_body_30_S1            germline cell
# ...                                                            ...
# TTTGGAGTCCTTGACC-f8548b44__FCA27_Female_body_adult   germline cell
# TTTGGAGTCGAACGGA-f8548b44__FCA27_Female_body_adult   germline cell
# TTTGGTTTCCCAAGCG-f8548b44__FCA27_Female_body_adult   germline cell
# TTTGTTGAGGGCTGAT-f8548b44__FCA27_Female_body_adult   germline cell
# TTTGTTGCAACTCGTA-f8548b44__FCA27_Female_body_adult   germline cell
#
#                                                    afca_annotation_broad  \
# AAAGGTATCACTTCTA-1_AFCA_female_body_30_S1           female germline cell
# AACCCAACACCCTATC-1_AFCA_female_body_30_S1           female germline cell
# AACGAAATCTATTTCG-1_AFCA_female_body_30_S1           female germline cell
# AAGAACAAGGACAACC-1_AFCA_female_body_30_S1           female germline cell
# AAGCATCTCAAGAGTA-1_AFCA_female_body_30_S1           female germline cell
# ...                                                                  ...
# TTTGGAGTCCTTGACC-f8548b44__FCA27_Female_body_adult  female germline cell
# TTTGGAGTCGAACGGA-f8548b44__FCA27_Female_body_adult  female germline cell
# TTTGGTTTCCCAAGCG-f8548b44__FCA27_Female_body_adult  female germline cell
# TTTGTTGAGGGCTGAT-f8548b44__FCA27_Female_body_adult  female germline cell
# TTTGTTGCAACTCGTA-f8548b44__FCA27_Female_body_adult  female germline cell
#
#                                                                       indiv
# AAAGGTATCACTTCTA-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AACCCAACACCCTATC-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AACGAAATCTATTTCG-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AAGAACAAGGACAACC-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AAGCATCTCAAGAGTA-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ...                                                                     ...
# TTTGGAGTCCTTGACC-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTGGAGTCGAACGGA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTGGTTTCCCAAGCG-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTGTTGAGGGCTGAT-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTGTTGCAACTCGTA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
#
# [3824 rows x 3 columns]
#
# 	Saved the new adata object to:  /hpc/shared/onco_janssen/dhaynessimmons/data/ageing_flies/afca_data/base_body_h5ad_data/ct_specific/germline_cell.h5ad
#
#
#
# Working on cell type:  enterocyte of posterior adult midgut epithelium
#
# number of cells:  751
# Min number of genes expressed :  263
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  40
# Not enough cells in an age group to proceed with analysis
#
#
# Working on cell type:  cardia (1)
#
# number of cells:  1062
# Min number of genes expressed :  298
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  42
# Not enough cells in an age group to proceed with analysis
#
#
# Working on cell type:  antimicrobial peptide-producing cell
#
# number of cells:  104
# Min number of genes expressed :  390
# Not enough cells to proceed with analysis
#
#
# Working on cell type:  female reproductive system
#
# number of cells:  1219
# Min number of genes expressed :  287
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  256
# Sufficient cells in each age group to proceed with analysis
#
# shape of cell type data:  (1219, 15992)
#
# shape of cell type data after filtering:  (1219, 9363)
# Columns in the observation dataframe:  Index(['tissue', 'sex', 'age', 'sex_age', 'n_genes_by_counts', 'total_counts',
#        'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts',
#        'log1p_total_counts', 'log1p_total_counts_mt', 'dataset',
#        'fca_annotation', 'afca_annotation', 'afca_annotation_broad', 'indiv'],
#       dtype='object')
#                                                                afca_annotation  \
# AACAACCGTCCGCAGT-1_AFCA_female_body_30_S1           female reproductive system
# ACGGGTCGTACACGTT-1_AFCA_female_body_30_S1           female reproductive system
# ACGGTCGGTGCCTAAT-1_AFCA_female_body_30_S1           female reproductive system
# ACTATTCCACTATCCC-1_AFCA_female_body_30_S1           female reproductive system
# AGGACTTTCTTCCTAA-1_AFCA_female_body_30_S1           female reproductive system
# ...                                                                        ...
# TTCCACGTCGATTGAC-f8548b44__FCA27_Female_body_adult  female reproductive system
# TTCGGTCGTGATTCTG-f8548b44__FCA27_Female_body_adult  female reproductive system
# TTCTTCCTCCGATCGG-f8548b44__FCA27_Female_body_adult  female reproductive system
# TTCTTGAAGGGCAACT-f8548b44__FCA27_Female_body_adult  female reproductive system
# TTGGGCGGTAGTGGCA-f8548b44__FCA27_Female_body_adult  female reproductive system
#
#                                                        afca_annotation_broad  \
# AACAACCGTCCGCAGT-1_AFCA_female_body_30_S1           male reproductive system
# ACGGGTCGTACACGTT-1_AFCA_female_body_30_S1           male reproductive system
# ACGGTCGGTGCCTAAT-1_AFCA_female_body_30_S1           male reproductive system
# ACTATTCCACTATCCC-1_AFCA_female_body_30_S1           male reproductive system
# AGGACTTTCTTCCTAA-1_AFCA_female_body_30_S1           male reproductive system
# ...                                                                      ...
# TTCCACGTCGATTGAC-f8548b44__FCA27_Female_body_adult  male reproductive system
# TTCGGTCGTGATTCTG-f8548b44__FCA27_Female_body_adult  male reproductive system
# TTCTTCCTCCGATCGG-f8548b44__FCA27_Female_body_adult  male reproductive system
# TTCTTGAAGGGCAACT-f8548b44__FCA27_Female_body_adult  male reproductive system
# TTGGGCGGTAGTGGCA-f8548b44__FCA27_Female_body_adult  male reproductive system
#
#                                                                       indiv
# AACAACCGTCCGCAGT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ACGGGTCGTACACGTT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ACGGTCGGTGCCTAAT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ACTATTCCACTATCCC-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AGGACTTTCTTCCTAA-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ...                                                                     ...
# TTCCACGTCGATTGAC-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTCGGTCGTGATTCTG-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTCTTCCTCCGATCGG-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTCTTGAAGGGCAACT-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTGGGCGGTAGTGGCA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
#
# [1219 rows x 3 columns]
#
# 	Saved the new adata object to:  /hpc/shared/onco_janssen/dhaynessimmons/data/ageing_flies/afca_data/base_body_h5ad_data/ct_specific/female_reproductive_system.h5ad
#
#
#
# Working on cell type:  scolopidial neuron
#
# number of cells:  1295
# Min number of genes expressed :  278
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  211
# Sufficient cells in each age group to proceed with analysis
#
# shape of cell type data:  (1295, 15992)
#
# shape of cell type data after filtering:  (1295, 9026)
# Columns in the observation dataframe:  Index(['tissue', 'sex', 'age', 'sex_age', 'n_genes_by_counts', 'total_counts',
#        'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts',
#        'log1p_total_counts', 'log1p_total_counts_mt', 'dataset',
#        'fca_annotation', 'afca_annotation', 'afca_annotation_broad', 'indiv'],
#       dtype='object')
#                                                        afca_annotation  \
# AACCATGGTCCGACGT-1_AFCA_female_body_30_S1           scolopidial neuron
# AAGTCGTAGATAGCAT-1_AFCA_female_body_30_S1           scolopidial neuron
# ACGTAACCAGGCCCTA-1_AFCA_female_body_30_S1           scolopidial neuron
# AGATCGTAGCTTCGTA-1_AFCA_female_body_30_S1           scolopidial neuron
# AGGTTACCAGGTCCCA-1_AFCA_female_body_30_S1           scolopidial neuron
# ...                                                                ...
# GTTACAGAGCTGGAGT-f8548b44__FCA27_Female_body_adult  scolopidial neuron
# TCTTGCGTCAAGCTGT-f8548b44__FCA27_Female_body_adult  scolopidial neuron
# TGCTCGTTCGACATCA-f8548b44__FCA27_Female_body_adult  scolopidial neuron
# TGTTTGTTCTACTCAT-f8548b44__FCA27_Female_body_adult  scolopidial neuron
# TTGATGGCATTGCTTT-f8548b44__FCA27_Female_body_adult  scolopidial neuron
#
#                                                    afca_annotation_broad  \
# AACCATGGTCCGACGT-1_AFCA_female_body_30_S1                 sensory neuron
# AAGTCGTAGATAGCAT-1_AFCA_female_body_30_S1                 sensory neuron
# ACGTAACCAGGCCCTA-1_AFCA_female_body_30_S1                 sensory neuron
# AGATCGTAGCTTCGTA-1_AFCA_female_body_30_S1                 sensory neuron
# AGGTTACCAGGTCCCA-1_AFCA_female_body_30_S1                 sensory neuron
# ...                                                                  ...
# GTTACAGAGCTGGAGT-f8548b44__FCA27_Female_body_adult        sensory neuron
# TCTTGCGTCAAGCTGT-f8548b44__FCA27_Female_body_adult        sensory neuron
# TGCTCGTTCGACATCA-f8548b44__FCA27_Female_body_adult        sensory neuron
# TGTTTGTTCTACTCAT-f8548b44__FCA27_Female_body_adult        sensory neuron
# TTGATGGCATTGCTTT-f8548b44__FCA27_Female_body_adult        sensory neuron
#
#                                                                       indiv
# AACCATGGTCCGACGT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AAGTCGTAGATAGCAT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ACGTAACCAGGCCCTA-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AGATCGTAGCTTCGTA-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AGGTTACCAGGTCCCA-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ...                                                                     ...
# GTTACAGAGCTGGAGT-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TCTTGCGTCAAGCTGT-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TGCTCGTTCGACATCA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TGTTTGTTCTACTCAT-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTGATGGCATTGCTTT-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
#
# [1295 rows x 3 columns]
#
# 	Saved the new adata object to:  /hpc/shared/onco_janssen/dhaynessimmons/data/ageing_flies/afca_data/base_body_h5ad_data/ct_specific/scolopidial_neuron.h5ad
#
#
#
# Working on cell type:  adult salivary gland
#
# number of cells:  583
# Min number of genes expressed :  280
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  52
# Not enough cells in an age group to proceed with analysis
#
#
# Working on cell type:  intestinal stem cell
#
# number of cells:  2132
# Min number of genes expressed :  282
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  254
# Sufficient cells in each age group to proceed with analysis
#
# shape of cell type data:  (2132, 15992)
#
# shape of cell type data after filtering:  (2132, 9688)
# Columns in the observation dataframe:  Index(['tissue', 'sex', 'age', 'sex_age', 'n_genes_by_counts', 'total_counts',
#        'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts',
#        'log1p_total_counts', 'log1p_total_counts_mt', 'dataset',
#        'fca_annotation', 'afca_annotation', 'afca_annotation_broad', 'indiv'],
#       dtype='object')
#                                                          afca_annotation  \
# AACCATGGTTCCGCAG-1_AFCA_female_body_30_S1           intestinal stem cell
# ACACAGTTCCATTGCC-1_AFCA_female_body_30_S1           intestinal stem cell
# AGAAGTACACTACACA-1_AFCA_female_body_30_S1           intestinal stem cell
# AGAGAATCAAATACAG-1_AFCA_female_body_30_S1           intestinal stem cell
# ATGGATCTCTGCTTAT-1_AFCA_female_body_30_S1           intestinal stem cell
# ...                                                                  ...
# TTCAATCAGTCATGAA-f8548b44__FCA27_Female_body_adult  intestinal stem cell
# TTCTAACCATGCCGGT-f8548b44__FCA27_Female_body_adult  intestinal stem cell
# TTCTGTATCACAACCA-f8548b44__FCA27_Female_body_adult  intestinal stem cell
# TTTCACAAGCGCCCAT-f8548b44__FCA27_Female_body_adult  intestinal stem cell
# TTTCGATGTCGCACAC-f8548b44__FCA27_Female_body_adult  intestinal stem cell
#
#                                                      afca_annotation_broad  \
# AACCATGGTTCCGCAG-1_AFCA_female_body_30_S1           somatic precursor cell
# ACACAGTTCCATTGCC-1_AFCA_female_body_30_S1           somatic precursor cell
# AGAAGTACACTACACA-1_AFCA_female_body_30_S1           somatic precursor cell
# AGAGAATCAAATACAG-1_AFCA_female_body_30_S1           somatic precursor cell
# ATGGATCTCTGCTTAT-1_AFCA_female_body_30_S1           somatic precursor cell
# ...                                                                    ...
# TTCAATCAGTCATGAA-f8548b44__FCA27_Female_body_adult  somatic precursor cell
# TTCTAACCATGCCGGT-f8548b44__FCA27_Female_body_adult  somatic precursor cell
# TTCTGTATCACAACCA-f8548b44__FCA27_Female_body_adult  somatic precursor cell
# TTTCACAAGCGCCCAT-f8548b44__FCA27_Female_body_adult  somatic precursor cell
# TTTCGATGTCGCACAC-f8548b44__FCA27_Female_body_adult  somatic precursor cell
#
#                                                                       indiv
# AACCATGGTTCCGCAG-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ACACAGTTCCATTGCC-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AGAAGTACACTACACA-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AGAGAATCAAATACAG-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ATGGATCTCTGCTTAT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ...                                                                     ...
# TTCAATCAGTCATGAA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTCTAACCATGCCGGT-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTCTGTATCACAACCA-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTCACAAGCGCCCAT-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
# TTTCGATGTCGCACAC-f8548b44__FCA27_Female_body_adult  FCA27_Female_body_adult
#
# [2132 rows x 3 columns]
#
# 	Saved the new adata object to:  /hpc/shared/onco_janssen/dhaynessimmons/data/ageing_flies/afca_data/base_body_h5ad_data/ct_specific/intestinal_stem_cell.h5ad
#
#
#
# Working on cell type:  adult peripheral nervous system
#
# number of cells:  5889
# Min number of genes expressed :  255
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  737
# Sufficient cells in each age group to proceed with analysis
#
# shape of cell type data:  (5889, 15992)
#
# shape of cell type data after filtering:  (5889, 11696)
# Columns in the observation dataframe:  Index(['tissue', 'sex', 'age', 'sex_age', 'n_genes_by_counts', 'total_counts',
#        'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts',
#        'log1p_total_counts', 'log1p_total_counts_mt', 'dataset',
#        'fca_annotation', 'afca_annotation', 'afca_annotation_broad', 'indiv'],
#       dtype='object')
#                                                                     afca_annotation  \
# AACCCAACATTACGGT-1_AFCA_female_body_30_S1           adult peripheral nervous system
# ACATCCCAGGGCAAGG-1_AFCA_female_body_30_S1           adult peripheral nervous system
# ACCCTCAAGGCGACAT-1_AFCA_female_body_30_S1           adult peripheral nervous system
# AGATCGTCACAGCCTG-1_AFCA_female_body_30_S1           adult peripheral nervous system
# AGGAGGTTCCATTGTT-1_AFCA_female_body_30_S1           adult peripheral nervous system
# ...                                                                             ...
# TTCGCTGGTAGTCACT-f8548b44__FCA27_Female_body_adult  adult peripheral nervous system
# TTGGGCGAGACCATAA-f8548b44__FCA27_Female_body_adult  adult peripheral nervous system
# TTGTGGAAGATTAGCA-f8548b44__FCA27_Female_body_adult  adult peripheral nervous system
# TTGTTTGGTTATTCCT-f8548b44__FCA27_Female_body_adult  adult peripheral nervous system
# TTTACGTGTTACACAC-f8548b44__FCA27_Female_body_adult  adult peripheral nervous system
#
#                                                    afca_annotation_broad  \
# AACCCAACATTACGGT-1_AFCA_female_body_30_S1                     CNS neuron
# ACATCCCAGGGCAAGG-1_AFCA_female_body_30_S1                     CNS neuron
# ACCCTCAAGGCGACAT-1_AFCA_female_body_30_S1                     CNS neuron
# AGATCGTCACAGCCTG-1_AFCA_female_body_30_S1                     CNS neuron
# AGGAGGTTCCATTGTT-1_AFCA_female_body_30_S1                     CNS neuron
# ...                                                                  ...
# TTCGCTGGTAGTCACT-f8548b44__FCA27_Female_body_adult            CNS neuron
# TTGGGCGAGACCATAA-f8548b44__FCA27_Female_body_adult            CNS neuron
# TTGTGGAAGATTAGCA-f8548b44__FCA27_Female_body_adult            CNS neuron
# TTGTTTGGTTATTCCT-f8548b44__FCA27_Female_body_adult            CNS neuron
# TTTACGTGTTACACAC-f8548b44__FCA27_Female_body_adult            CNS neuron
#
#                                                                       indiv
# AACCCAACATTACGGT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ACATCCCAGGGCAAGG-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ACCCTCAAGGCGACAT-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# AGATCGTCACAGCCTG-1_AFCA_female_body_30_S1            AFCA_female_body_30_S1
# ...
# TTAGGCAGTGGCCACT-f84bfd1c__FCA26_Female_body_adult  subperineurial glial cell_body
# TTGTTCAAGTATTGCC-f84bfd1c__FCA26_Female_body_adult  subperineurial glial cell_body
#
#                                                    afca_annotation_broad  \
# ACACAGTAGTCTCCTC-1_AFCA_female_body_30_S4                     glial cell
# ACACTGAGTATGTGTC-1_AFCA_female_body_30_S4                     glial cell
# ACTTCGCCACGCTATA-1_AFCA_female_body_30_S4                     glial cell
# AGGATAACACACCGCA-1_AFCA_female_body_30_S4                     glial cell
# AGTAGTCCAACAGAGC-1_AFCA_female_body_30_S4                     glial cell
# ...                                                                  ...
# TCCATGCGTATTGAGA-f84bfd1c__FCA26_Female_body_adult            glial cell
# TCTCAGCAGACCAAGC-f84bfd1c__FCA26_Female_body_adult            glial cell
# TGAATGCGTGTGTCGC-f84bfd1c__FCA26_Female_body_adult            glial cell
# TTAGGCAGTGGCCACT-f84bfd1c__FCA26_Female_body_adult            glial cell
# TTGTTCAAGTATTGCC-f84bfd1c__FCA26_Female_body_adult            glial cell
#
#                                                                       indiv
# ACACAGTAGTCTCCTC-1_AFCA_female_body_30_S4            AFCA_female_body_30_S4
# ACACTGAGTATGTGTC-1_AFCA_female_body_30_S4            AFCA_female_body_30_S4
# ACTTCGCCACGCTATA-1_AFCA_female_body_30_S4            AFCA_female_body_30_S4
# AGGATAACACACCGCA-1_AFCA_female_body_30_S4            AFCA_female_body_30_S4
# AGTAGTCCAACAGAGC-1_AFCA_female_body_30_S4            AFCA_female_body_30_S4
# ...                                                                     ...
# TCCATGCGTATTGAGA-f84bfd1c__FCA26_Female_body_adult  FCA26_Female_body_adult
# TCTCAGCAGACCAAGC-f84bfd1c__FCA26_Female_body_adult  FCA26_Female_body_adult
# TGAATGCGTGTGTCGC-f84bfd1c__FCA26_Female_body_adult  FCA26_Female_body_adult
# TTAGGCAGTGGCCACT-f84bfd1c__FCA26_Female_body_adult  FCA26_Female_body_adult
# TTGTTCAAGTATTGCC-f84bfd1c__FCA26_Female_body_adult  FCA26_Female_body_adult
#
# [1431 rows x 3 columns]
#
# 	Saved the new adata object to:  /hpc/shared/onco_janssen/dhaynessimmons/data/ageing_flies/afca_data/base_body_h5ad_data/ct_specific/subperineurial_glial_cell_body.h5ad
#
#
#
# Working on cell type:  adult Malpighian tubule principal cell of initial segment
#
# number of cells:  70
# Min number of genes expressed :  295
# Not enough cells to proceed with analysis
#
#
# Working on cell type:  CNS surface associated glial cell
#
# number of cells:  208
# Min number of genes expressed :  271
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  31
# Not enough cells in an age group to proceed with analysis
#
#
# Working on cell type:  adult reticular neuropil associated glial cell_body
#
# number of cells:  521
# Min number of genes expressed :  255
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  29
# Not enough cells in an age group to proceed with analysis
#
#
# Working on cell type:  adult Malpighian tubule stellate cell of main segment
#
# number of cells:  10
# Min number of genes expressed :  675
# Not enough cells to proceed with analysis
#
#
# Working on cell type:  seminal vesicle & testis epithelia
#
# number of cells:  635
# Min number of genes expressed :  253
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  121
# Sufficient cells in each age group to proceed with analysis
#
# shape of cell type data:  (635, 15992)
#
# shape of cell type data after filtering:  (635, 8429)
# Columns in the observation dataframe:  Index(['tissue', 'sex', 'age', 'sex_age', 'n_genes_by_counts', 'total_counts',
#        'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts',
#        'log1p_total_counts', 'log1p_total_counts_mt', 'dataset',
#        'fca_annotation', 'afca_annotation', 'afca_annotation_broad', 'indiv'],
#       dtype='object')
#                                                                      afca_annotation  \
# AAAGAACGTTGGGTAG-1_AFCA_male_body_30_S1           seminal vesicle & testis epithelia
# AAAGTCCAGCAAATCA-1_AFCA_male_body_30_S1           seminal vesicle & testis epithelia
# AACCCAATCAAGCTTG-1_AFCA_male_body_30_S1           seminal vesicle & testis epithelia
# AACCTTTGTCCAAGAG-1_AFCA_male_body_30_S1           seminal vesicle & testis epithelia
# AAGAACAAGCCGTTAT-1_AFCA_male_body_30_S1           seminal vesicle & testis epithelia
# ...                                                                              ...
# TTACTGTAGGCCTTGC-f82124ca__FCA21_Male_body_adult  seminal vesicle & testis epithelia
# TTCACCGTCCGACATA-f82124ca__FCA21_Male_body_adult  seminal vesicle & testis epithelia
# TTGGGCGGTCACTACA-f82124ca__FCA21_Male_body_adult  seminal vesicle & testis epithelia
# TTTCGATTCGAACACT-f82124ca__FCA21_Male_body_adult  seminal vesicle & testis epithelia
# TTTGGTTAGATGGCGT-f82124ca__FCA21_Male_body_adult  seminal vesicle & testis epithelia
#
#                                                      afca_annotation_broad  \
# AAAGAACGTTGGGTAG-1_AFCA_male_body_30_S1           male reproductive system
# AAAGTCCAGCAAATCA-1_AFCA_male_body_30_S1           male reproductive system
# AACCCAATCAAGCTTG-1_AFCA_male_body_30_S1           male reproductive system
# AACCTTTGTCCAAGAG-1_AFCA_male_body_30_S1           male reproductive system
# AAGAACAAGCCGTTAT-1_AFCA_male_body_30_S1           male reproductive system
# ...                                                                    ...
# TTACTGTAGGCCTTGC-f82124ca__FCA21_Male_body_adult  male reproductive system
# TTCACCGTCCGACATA-f82124ca__FCA21_Male_body_adult  male reproductive system
# TTGGGCGGTCACTACA-f82124ca__FCA21_Male_body_adult  male reproductive system
# TTTCGATTCGAACACT-f82124ca__FCA21_Male_body_adult  male reproductive system
# TTTGGTTAGATGGCGT-f82124ca__FCA21_Male_body_adult  male reproductive system
#
#                                                                   indiv
# AAAGAACGTTGGGTAG-1_AFCA_male_body_30_S1            AFCA_male_body_30_S1
# AAAGTCCAGCAAATCA-1_AFCA_male_body_30_S1            AFCA_male_body_30_S1
# AACCCAATCAAGCTTG-1_AFCA_male_body_30_S1            AFCA_male_body_30_S1
# AACCTTTGTCCAAGAG-1_AFCA_male_body_30_S1            AFCA_male_body_30_S1
# AAGAACAAGCCGTTAT-1_AFCA_male_body_30_S1            AFCA_male_body_30_S1
# ...                                                                 ...
# TTACTGTAGGCCTTGC-f82124ca__FCA21_Male_body_adult  FCA21_Male_body_adult
# TTCACCGTCCGACATA-f82124ca__FCA21_Male_body_adult  FCA21_Male_body_adult
# TTGGGCGGTCACTACA-f82124ca__FCA21_Male_body_adult  FCA21_Male_body_adult
# TTTCGATTCGAACACT-f82124ca__FCA21_Male_body_adult  FCA21_Male_body_adult
# TTTGGTTAGATGGCGT-f82124ca__FCA21_Male_body_adult  FCA21_Male_body_adult
#
# [635 rows x 3 columns]
#
# 	Saved the new adata object to:  /hpc/shared/onco_janssen/dhaynessimmons/data/ageing_flies/afca_data/base_body_h5ad_data/ct_specific/seminal_vesicle_&_testis_epithelia.h5ad
#
#
#
# Working on cell type:  ejaculatory bulb
#
# number of cells:  1401
# Min number of genes expressed :  285
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  125
# Sufficient cells in each age group to proceed with analysis
#
# shape of cell type data:  (1401, 15992)
#
# shape of cell type data after filtering:  (1401, 9613)
# Columns in the observation dataframe:  Index(['tissue', 'sex', 'age', 'sex_age', 'n_genes_by_counts', 'total_counts',
#        'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts',
#        'log1p_total_counts', 'log1p_total_counts_mt', 'dataset',
#        'fca_annotation', 'afca_annotation', 'afca_annotation_broad', 'indiv'],
#       dtype='object')
#                                                    afca_annotation  \
# AAAGTGAAGGCGACAT-1_AFCA_male_body_30_S1           ejaculatory bulb
# AACCTGACATCCTGTC-1_AFCA_male_body_30_S1           ejaculatory bulb
# AAGACTCAGACGCTCC-1_AFCA_male_body_30_S1           ejaculatory bulb
# AAGGAATGTCCGCAGT-1_AFCA_male_body_30_S1           ejaculatory bulb
# AAGTCGTTCACTTGTT-1_AFCA_male_body_30_S1           ejaculatory bulb
# ...                                                            ...
# TTCCGTGCAAATCAGA-f82124ca__FCA21_Male_body_adult  ejaculatory bulb
# TTCCTAAAGGCCTGCT-f82124ca__FCA21_Male_body_adult  ejaculatory bulb
# TTGAACGAGCAGTACG-f82124ca__FCA21_Male_body_adult  ejaculatory bulb
# TTGGATGAGAGGTCGT-f82124ca__FCA21_Male_body_adult  ejaculatory bulb
# TTGTGGACAACAAGAT-f82124ca__FCA21_Male_body_adult  ejaculatory bulb
#
#                                                  afca_annotation_broad  \
# AAAGTGAAGGCGACAT-1_AFCA_male_body_30_S1                          gland
# AACCTGACATCCTGTC-1_AFCA_male_body_30_S1                          gland
# AAGACTCAGACGCTCC-1_AFCA_male_body_30_S1                          gland
# AAGGAATGTCCGCAGT-1_AFCA_male_body_30_S1                          gland
# AAGTCGTTCACTTGTT-1_AFCA_male_body_30_S1                          gland
# ...                                                                ...
# TTCCGTGCAAATCAGA-f82124ca__FCA21_Male_body_adult                 gland
# TTCCTAAAGGCCTGCT-f82124ca__FCA21_Male_body_adult                 gland
# TTGAACGAGCAGTACG-f82124ca__FCA21_Male_body_adult                 gland
# TTGGATGAGAGGTCGT-f82124ca__FCA21_Male_body_adult                 gland
# TTGTGGACAACAAGAT-f82124ca__FCA21_Male_body_adult                 gland
#
#                                                                   indiv
# AAAGTGAAGGCGACAT-1_AFCA_male_body_30_S1            AFCA_male_body_30_S1
# AACCTGACATCCTGTC-1_AFCA_male_body_30_S1            AFCA_male_body_30_S1
# AAGACTCAGACGCTCC-1_AFCA_male_body_30_S1            AFCA_male_body_30_S1
# AAGGAATGTCCGCAGT-1_AFCA_male_body_30_S1            AFCA_male_body_30_S1
# AAGTCGTTCACTTGTT-1_AFCA_male_body_30_S1            AFCA_male_body_30_S1
# ...                                                                 ...
# TTCCGTGCAAATCAGA-f82124ca__FCA21_Male_body_adult  FCA21_Male_body_adult
# TTCCTAAAGGCCTGCT-f82124ca__FCA21_Male_body_adult  FCA21_Male_body_adult
# TTGAACGAGCAGTACG-f82124ca__FCA21_Male_body_adult  FCA21_Male_body_adult
# TTGGATGAGAGGTCGT-f82124ca__FCA21_Male_body_adult  FCA21_Male_body_adult
# TTGTGGACAACAAGAT-f82124ca__FCA21_Male_body_adult  FCA21_Male_body_adult
#
# [1401 rows x 3 columns]
#
# 	Saved the new adata object to:  /hpc/shared/onco_janssen/dhaynessimmons/data/ageing_flies/afca_data/base_body_h5ad_data/ct_specific/ejaculatory_bulb.h5ad
#
#
#
# Working on cell type:  ejaculatory bulb epithelium
#
# number of cells:  549
# Min number of genes expressed :  334
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  56
# Not enough cells in an age group to proceed with analysis
#
#
# Working on cell type:  anterior ejaculatory duct
#
# number of cells:  189
# Min number of genes expressed :  280
# Not enough cells to proceed with analysis
#
#
# Working on cell type:  male accessory gland main cell
#
# number of cells:  2015
# Min number of genes expressed :  265
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  225
# Sufficient cells in each age group to proceed with analysis
#
# shape of cell type data:  (2015, 15992)
#
# shape of cell type data after filtering:  (2015, 10977)
# Columns in the observation dataframe:  Index(['tissue', 'sex', 'age', 'sex_age', 'n_genes_by_counts', 'total_counts',
#        'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts',
#        'log1p_total_counts', 'log1p_total_counts_mt', 'dataset',
#        'fca_annotation', 'afca_annotation', 'afca_annotation_broad', 'indiv'],
#       dtype='object')
#                                                                  afca_annotation  \
# AAGACTCAGATCCCGC-1_AFCA_male_body_30_S1           male accessory gland main cell
# AAGCGAGAGCAAACAT-1_AFCA_male_body_30_S1           male accessory gland main cell
# AAGCGAGTCCCTCGTA-1_AFCA_male_body_30_S1           male accessory gland main cell
# AATGGCTGTTGGGTTT-1_AFCA_male_body_30_S1           male accessory gland main cell
# ACACGCGTCATTGCTT-1_AFCA_male_body_30_S1           male accessory gland main cell
# ...                                                                          ...
# TTCATGTTCCCAGGAC-f82124ca__FCA21_Male_body_adult  male accessory gland main cell
# TTCCTTCCAGCAAGAC-f82124ca__FCA21_Male_body_adult  male accessory gland main cell
# TTCTAACAGCGACAGT-f82124ca__FCA21_Male_body_adult  male accessory gland main cell
# TTTACGTGTGTGACCC-f82124ca__FCA21_Male_body_adult  male accessory gland main cell
# TTTGACTGTAGATTAG-f82124ca__FCA21_Male_body_adult  male accessory gland main cell
#
#                                                  afca_annotation_broad  \
# AAGACTCAGATCCCGC-1_AFCA_male_body_30_S1                          gland
# AAGCGAGAGCAAACAT-1_AFCA_male_body_30_S1                          gland
# AAGCGAGTCCCTCGTA-1_AFCA_male_body_30_S1                          gland
# AATGGCTGTTGGGTTT-1_AFCA_male_body_30_S1                          gland
# ACACGCGTCATTGCTT-1_AFCA_male_body_30_S1                          gland
# ...                                                                ...
# TTCATGTTCCCAGGAC-f82124ca__FCA21_Male_body_adult                 gland
# TTCCTTCCAGCAAGAC-f82124ca__FCA21_Male_body_adult                 gland
# TTCTAACAGCGACAGT-f82124ca__FCA21_Male_body_adult                 gland
# TTTACGTGTGTGACCC-f82124ca__FCA21_Male_body_adult                 gland
# TTTGACTGTAGATTAG-f82124ca__FCA21_Male_body_adult                 gland
#
#                                                                   indiv
# AAGACTCAGATCCCGC-1_AFCA_male_body_30_S1            AFCA_male_body_30_S1
# AAGCGAGAGCAAACAT-1_AFCA_male_body_30_S1            AFCA_male_body_30_S1
# AAGCGAGTCCCTCGTA-1_AFCA_male_body_30_S1            AFCA_male_body_30_S1
# AATGGCTGTTGGGTTT-1_AFCA_male_body_30_S1            AFCA_male_body_30_S1
# ACACGCGTCATTGCTT-1_AFCA_male_body_30_S1            AFCA_male_body_30_S1
# ...                                                                 ...
# TTCATGTTCCCAGGAC-f82124ca__FCA21_Male_body_adult  FCA21_Male_body_adult
# TTCCTTCCAGCAAGAC-f82124ca__FCA21_Male_body_adult  FCA21_Male_body_adult
# TTCTAACAGCGACAGT-f82124ca__FCA21_Male_body_adult  FCA21_Male_body_adult
# TTTACGTGTGTGACCC-f82124ca__FCA21_Male_body_adult  FCA21_Male_body_adult
# TTTGACTGTAGATTAG-f82124ca__FCA21_Male_body_adult  FCA21_Male_body_adult
#
# [2015 rows x 3 columns]
#
# 	Saved the new adata object to:  /hpc/shared/onco_janssen/dhaynessimmons/data/ageing_flies/afca_data/base_body_h5ad_data/ct_specific/male_accessory_gland_main_cell.h5ad
#
#
#
# Working on cell type:  spermatid
#
# number of cells:  131
# Min number of genes expressed :  203
# Not enough cells to proceed with analysis
#
#
# Working on cell type:  cyst cell
#
# number of cells:  201
# Min number of genes expressed :  207
# Sufficient cells to proceed with analysis
# Minimum number of cells in an age group:  26
# Not enough cells in an age group to proceed with analysis
#
#
# Working on cell type:  male accessory gland secondary cell
#
# number of cells:  20
# Min number of genes expressed :  336
# Not enough cells to proceed with analysis
#
#
# Working on cell type:  spermatocyte
#
# number of cells:  90
# Min number of genes expressed :  224
# Not enough cells to proceed with analysis
# ['follicle cell', 'adult fat body_body', 'adult hindgut', 'adult oenocyte', 'hemocyte_body', 'adult tracheal cell', 'crop', 'adult ventral nervous system', 'germline cell', 'female reproductive system', 'scolopidial neuron', 'intestinal stem cell', 'adult peripheral nervous system', 'mechanosensory neuron of haltere', 'epithelial cell_body', 'eo support cell', 'pheromone-sensing neuron', 'enteroblast', 'oviduct', 'muscle cell', 'gustatory receptor neuron', 'indirect flight muscle', 'cell body glial cell', 'visceral muscle of the midgut', 'adult alary muscle', 'adult glial cell', 'perineurial glial sheath', 'subperineurial glial cell_body', 'seminal vesicle & testis epithelia', 'ejaculatory bulb', 'male accessory gland main cell']
